# %% [markdown]
# # Notebook 07 — Feature Engineering
#
# **Mục tiêu**: Tạo bộ features cho mô hình dự báo doanh thu
# - Time features (seasonality, trend)
# - Lag features (doanh thu các kỳ trước)
# - Rolling statistics (moving average)
# - Business features (promotion flag, return rate, inventory level)
#
# **Tương ứng báo cáo**: Phần 2 — Chương 6.2 (Định hướng xây dựng mô hình)

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.data_loader import load_processed, save_processed
from src.feature_engineering import (
    add_time_features, add_lag_features, add_rolling_features,
    add_promotion_flags, encode_categorical
)

sns.set_theme(style='whitegrid')
# %matplotlib inline

# %%
sales      = load_processed('sales_clean.csv')
promotions = load_processed('promotions_clean.csv')
inventory  = load_processed('inventory_clean.csv')
web_traffic = load_processed('web_traffic_clean.csv')

print(sales.head())

# %% [markdown]
# ## 1. Chuẩn bị bảng sales theo thời gian

# %%
# TODO: Sort theo date, set index
# DATE_COL = 'date'  # thay bằng tên cột ngày thực tế
# sales = sales.sort_values(DATE_COL).reset_index(drop=True)
# sales[DATE_COL] = pd.to_datetime(sales[DATE_COL])

# %% [markdown]
# ## 2. Time features

# %%
# TODO:
# DATE_COL = 'date'
# sales = add_time_features(sales, DATE_COL)

# %% [markdown]
# ## 3. Lag features (doanh thu kỳ trước)

# %%
# TODO:
# sales = add_lag_features(sales, 'revenue', lags=[1, 7, 14, 30])
# Với time series daily: lag 1, 7, 14, 30 ngày
# Với time series monthly: lag 1, 3, 6, 12 tháng

# %% [markdown]
# ## 4. Rolling statistics

# %%
# TODO:
# sales = add_rolling_features(sales, 'revenue', windows=[7, 14, 30])

# %% [markdown]
# ## 5. Business features từ kết quả phân tích

# %%
# TODO: Merge các features từ bảng khác
# 1. Promotion flag: ngày có/không có khuyến mãi
# 2. Return rate theo tuần/tháng
# 3. Web traffic (sessions, pageviews)
# 4. Inventory level trung bình

# %% [markdown]
# ## 6. Lưu feature table

# %%
# sales_features = sales.dropna()  # drop rows có NaN do lag
# print(f'Feature table shape: {sales_features.shape}')
# print(f'Features: {sales_features.columns.tolist()}')
# save_processed(sales_features, 'sales_features.csv', subfolder='features')
