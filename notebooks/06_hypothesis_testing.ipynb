# %% [markdown]
# # Notebook 06 — Giả thuyết và Định lượng
#
# **Mục tiêu**: Đặt ra và kiểm chứng các giả thuyết từ kết quả phân tích NB05
# - Định lượng mức độ ảnh hưởng của từng yếu tố đến doanh thu
# - Xác định features quan trọng nhất cho mô hình
#
# **Tương ứng báo cáo**: Phần 2 — Chương 5.4 (Xây dựng và kiểm chứng giả thuyết)

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

from src.data_loader import load_processed

sns.set_theme(style='whitegrid')
# %matplotlib inline

# %% [markdown]
# ## Giả thuyết 1: Khuyến mãi có tác động tích cực đến doanh thu
#
# - **H0**: Doanh thu trong thời gian khuyến mãi = Doanh thu bình thường
# - **H1**: Doanh thu trong thời gian khuyến mãi > Doanh thu bình thường
# - **Phương pháp**: t-test hoặc Mann-Whitney U test

# %%
# TODO:
# revenue_promo     = sales[sales['has_promotion'] == 1]['revenue']
# revenue_no_promo  = sales[sales['has_promotion'] == 0]['revenue']
# t_stat, p_value   = stats.ttest_ind(revenue_promo, revenue_no_promo)
# print(f'p-value: {p_value:.4f}')
# Kết luận: Bác bỏ/Chấp nhận H0?

# %% [markdown]
# ## Giả thuyết 2: Tỉ lệ trả hàng cao làm giảm doanh thu
#
# - **H0**: Không có mối tương quan giữa return rate và revenue
# - **H1**: Return rate cao tương quan âm với revenue

# %%
# TODO:
# Tính return rate theo tháng
# Tính correlation với revenue theo tháng
# Scatter plot + regression line

# %% [markdown]
# ## Giả thuyết 3: Web traffic có khả năng dự báo doanh thu
#
# - **H0**: Web traffic không có tương quan với doanh thu
# - **H1**: Web traffic tương quan dương với doanh thu

# %%
# TODO:
# Correlation matrix: web_traffic metrics vs revenue
# Granger causality test (optional)

# %% [markdown]
# ## Tóm tắt kết quả kiểm chứng
#
# | Giả thuyết | Kết quả | p-value | Kết luận |
# |------------|---------|---------|----------|
# | H1: Promotion → Revenue | | | |
# | H2: Return rate → Revenue | | | |
# | H3: Web traffic → Revenue | | | |
#
# → **Các features quan trọng cho mô hình**: ...
